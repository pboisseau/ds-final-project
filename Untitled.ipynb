# %%
pip install nfl_data_py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import nfl_data_py as nfl

# %%
nfl.import_pbp_data([2021], downcast=True, cache=False, alt_path=None)
# Out:
# 2021 done.
# Downcasting floats.
#        play_id          game_id old_game_id home_team away_team season_type  \
# 0          1.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 1         40.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 2         55.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 3         76.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 4        100.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# ...        ...              ...         ...       ...       ...         ...
# 50707   3930.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50708   3951.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50709   3968.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50710   3990.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50711   4011.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
#
# ...

# %%
nfl.import_rosters([2021])
# Out:
#       season  team position depth_chart_position  jersey_number    status  \
# 0     2021.0   ARI       CB                  RCB              7    Active
# 1     2021.0   ARI       CB                  LCB             21    Active
# 2     2021.0   ARI       CB                  RCB             33    Active
# 3     2021.0   ARI       CB                 None             39    Active
# 4     2021.0   ARI       CB                 None             24    Active
# ...      ...   ...      ...                  ...            ...       ...
# 4834  2021.0  None       WR                 None             81  Inactive
# 4835  2021.0  None       WR                 None             86    Active
# 4836  2021.0  None       WR                 None             87  Inactive
# 4837  2021.0  None       WR                 None              0  Inactive
# 4838  2021.0  None       WR                 None             80  Inactive
#
#            player_name first_name  last_name birth_date  ...    espn_id  \
# ...

# %%
nfl.import_ngs_data('receiving')
# Out:
#       season season_type  week    player_display_name player_position  \
# 0       2016         REG     0            Tyreek Hill              WR
# 1       2016         REG     0        Richard Rodgers              TE
# 2       2016         REG     0        Travis Benjamin              WR
# 3       2016         REG     0  Cordarrelle Patterson              WR
# 4       2016         REG     0         DeSean Jackson              WR
# ...      ...         ...   ...                    ...             ...
# 8947    2021        POST    23            Tee Higgins              WR
# 8948    2021        POST    23          Ja'Marr Chase              WR
# 8949    2021        POST    23          Van Jefferson              WR
# 8950    2021        POST    23          Ben Skowronek              WR
# 8951    2021        POST    23             Tyler Boyd              WR
#
#      team_abbr  avg_cushion  avg_separation  avg_intended_air_yards  \
# ...
