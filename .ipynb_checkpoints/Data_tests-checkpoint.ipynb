# %%
pip install nfl_data_py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import nfl_data_py as nfl

# %%
df7 = nfl.import_ngs_data('receiving')
df7
# Out:
#       season season_type  week    player_display_name player_position  \
# 0       2016         REG     0            Tyreek Hill              WR
# 1       2016         REG     0        Richard Rodgers              TE
# 2       2016         REG     0        Travis Benjamin              WR
# 3       2016         REG     0  Cordarrelle Patterson              WR
# 4       2016         REG     0         DeSean Jackson              WR
# ...      ...         ...   ...                    ...             ...
# 8947    2021        POST    23            Tee Higgins              WR
# 8948    2021        POST    23          Ja'Marr Chase              WR
# 8949    2021        POST    23          Van Jefferson              WR
# 8950    2021        POST    23          Ben Skowronek              WR
# 8951    2021        POST    23             Tyler Boyd              WR
#
#      team_abbr  avg_cushion  avg_separation  avg_intended_air_yards  \
# ...

# %%
df8 = df7[df7['player_display_name'] == 'Tyreek Hill']

df9 = df8[(df8['season'] == 2021) & (df8['season_type'] == 'REG')]
df9.columns
# Out:
# Index(['season', 'season_type', 'week', 'player_display_name',
#        'player_position', 'team_abbr', 'avg_cushion', 'avg_separation',
#        'avg_intended_air_yards', 'percent_share_of_intended_air_yards',
#        'receptions', 'targets', 'catch_percentage', 'yards', 'rec_touchdowns',
#        'avg_yac', 'avg_expected_yac', 'avg_yac_above_expectation',
#        'player_gsis_id', 'player_first_name', 'player_last_name',
#        'player_jersey_number', 'player_short_name'],
#       dtype='object')

# %%
df = nfl.import_weekly_data([2021])

df1 = df[df['player_id'] == '00-0033040']

df1
# Out:
# Downcasting floats.
#        player_id player_name recent_team  season  week season_type  \
# 1759  00-0033040      T.Hill          KC    2021     1         REG
# 1760  00-0033040      T.Hill          KC    2021     2         REG
# 1761  00-0033040      T.Hill          KC    2021     3         REG
# 1762  00-0033040      T.Hill          KC    2021     4         REG
# 1763  00-0033040      T.Hill          KC    2021     5         REG
# 1764  00-0033040      T.Hill          KC    2021     6         REG
# 1765  00-0033040      T.Hill          KC    2021     7         REG
# 1766  00-0033040      T.Hill          KC    2021     8         REG
# 1767  00-0033040      T.Hill          KC    2021     9         REG
# 1768  00-0033040      T.Hill          KC    2021    10         REG
# 1769  00-0033040      T.Hill          KC    2021    11         REG
# 1770  00-0033040      T.Hill          KC    2021    13         REG
# 1771  00-0033040      T.Hill          KC    2021    14         REG
# ...

# %%
nfl.see_weekly_cols()
# Out:
# Index(['player_id', 'player_name', 'recent_team', 'season', 'week',
#        'season_type', 'completions', 'attempts', 'passing_yards',
#        'passing_tds', 'interceptions', 'sacks', 'sack_yards', 'sack_fumbles',
#        'sack_fumbles_lost', 'passing_air_yards', 'passing_yards_after_catch',
#        'passing_first_downs', 'passing_epa', 'passing_2pt_conversions',
#        'dakota', 'carries', 'rushing_yards', 'rushing_tds', 'rushing_fumbles',
#        'rushing_fumbles_lost', 'rushing_first_downs', 'rushing_epa',
#        'rushing_2pt_conversions', 'receptions', 'targets', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles', 'receiving_fumbles_lost',
#        'receiving_air_yards', 'receiving_yards_after_catch',
#        'receiving_first_downs', 'receiving_epa', 'receiving_2pt_conversions',
#        'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr'],
#       dtype='object')

# %%
df2 = nfl.import_seasonal_data([2021])
df3 = df2[df2['player_id'] == '00-0033280']
df3['games']
# Out:
# 209    7
# Name: games, dtype: int64

# %%
df3.columns
# Out:
# Index(['player_id', 'season', 'season_type', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr_x', 'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr',
#        'games', 'tgt_sh', 'ay_sh', 'yac_sh', 'wopr_y', 'ry_sh', 'rtd_sh',
# ...

# %%
df4 = nfl.import_rosters([2021])
df5 = df4[df4['player_id'] == '00-0033040']
df5
# Out:
#       season team position depth_chart_position  jersey_number  status  \
# 1323    2021   KC       WR                   WR           10.0  Active
#
#       player_name first_name last_name birth_date  ... fantasy_data_id  \
# 1323  Tyreek Hill     Tyreek      Hill 1994-03-01  ...           18082
#
#       sleeper_id years_exp                                       headshot_url  \
# 1323        3321         5  https://static.www.nfl.com/image/private/f_aut...
#
#      ngs_position     esb_id gsis_it_id                              smart_id  \
# 1323           WR  HIL628694      43454  32004849-4c62-8694-8490-45499711dee4
#
#      entry_year rookie_year
# 1323       2016      2016.0
#
# [1 rows x 30 columns]

# %%
df5.columns
# Out:
# Index(['season', 'team', 'position', 'depth_chart_position', 'jersey_number',
#        'status', 'player_name', 'first_name', 'last_name', 'birth_date',
#        'height', 'weight', 'college', 'player_id', 'espn_id', 'sportradar_id',
#        'yahoo_id', 'rotowire_id', 'pff_id', 'pfr_id', 'fantasy_data_id',
#        'sleeper_id', 'years_exp', 'headshot_url', 'ngs_position', 'esb_id',
#        'gsis_it_id', 'smart_id', 'entry_year', 'rookie_year'],
#       dtype='object')

# %%
df10 = nfl.import_injuries([2021])
df11 = df10[df10['full_name'] == 'Christian McCaffrey']
df11
# Out:
#       season game_type team  week     gsis_id position            full_name  \
# 809     2021       REG  CAR     4  00-0033280       RB  Christian McCaffrey
# 1109    2021       REG  CAR     5  00-0033280       RB  Christian McCaffrey
# 1437    2021       REG  CAR     6  00-0033280       RB  Christian McCaffrey
#
#      first_name  last_name report_primary_injury report_secondary_injury  \
# 809   Christian  McCaffrey             Hamstring                    None
# 1109  Christian  McCaffrey             Hamstring                    None
# 1437  Christian  McCaffrey             Hamstring                    None
#
#      report_status practice_primary_injury practice_secondary_injury  \
# 809            Out               Hamstring                      None
# 1109      Doubtful               Hamstring                      None
# 1437           Out               Hamstring                      None
#
#                         practice_status       date_modified
# ...
